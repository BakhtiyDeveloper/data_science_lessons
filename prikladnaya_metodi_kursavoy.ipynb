# %% [markdown]
# <a href="https://colab.research.google.com/github/BakhtiyDeveloper/data_science_lessons/blob/main/prikladnaya_metodi_kursavoy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as st
from scipy.stats import shapiro
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats 
import seaborn as sns
from scipy import stats
from statsmodels. stats.weightstats import ztest as ztest
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import sklearn 
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
dt = [7.12,	9.42,	7.35,	8.61,	6.35,	6.46,	8.81,	11.78,	6.09,	10.73,	9.59,	6.52,	9.09,	10.23,	11.22,	8.92,	5.43,	11.24,	6.30,	9.36,
6.73,	10.57,	9.54,	7.56,	10.03,	8.23,	9.57,	7.44,	7.72, 4.71,	9.55,	4.27,	11.34,	7.24,	1.91,	6.89,	8.66,	12.65,	11.43,	6.69,
11.64,	3.03,	7.66,	8.14,	8.34,	5.13,	8.23,	6.45,	9.83,	9.58,	4.69,	7.41,	9.75,	6.27,	4.62,	8.02,	9.62,	10.20,	8.61,	8.09,
10.21,	10.15,	7.38,	8.90,	8.30,	7.65,	7.96,	4.17,	2.52,	7.04,	10.92,	9.08,	7.54,	6.79,	7.40,	12.19,	3.71,	6.10,	12.36,	10.36,
7.54,	10.03,	8.04,	8.74,	10.42,	5.99,	7.62,	5.96,	10.14,	10.19,	5.02,	6.35,	8.45,	8.66,	5.77,	9.87,	8.47,	5.99, 6.55,	10.15
]

# %%
col = ['dt']
df = pd.DataFrame(dt, columns=col)

# %%
df
# Out:
#      data
# 0    7.12
# 1    9.42
# 2    7.35
# 3    8.61
# 4    6.35
# ..    ...
# 95   9.87
# 96   8.47
# 97   5.99
# 98   6.55
# 99  10.15
#
# [100 rows x 1 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      data
# 0    7.12
# 1    9.42
# 2    7.35
# 3    8.61
# 4    6.35
# ..    ...
# 95   9.87
# 96   8.47
# 97   5.99
# 98   6.55
# 99  10.15
#
# [100 rows x 1 columns]>

# %%
df.hist(figsize = (12,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3fdedfddc0>]],
#       dtype=object)

# %%
plt.plot(df)
plt.show()

# %%
a =np.cumsum(df['dt'])
print(a.values)
# Out:
# [  7.12  16.54  23.89  32.5   38.85  45.31  54.12  65.9   71.99  82.72
#   92.31  98.83 107.92 118.15 129.37 138.29 143.72 154.96 161.26 170.62
#  177.35 187.92 197.46 205.02 215.05 223.28 232.85 240.29 248.01 252.72
#  262.27 266.54 277.88 285.12 287.03 293.92 302.58 315.23 326.66 333.35
#  344.99 348.02 355.68 363.82 372.16 377.29 385.52 391.97 401.8  411.38
#  416.07 423.48 433.23 439.5  444.12 452.14 461.76 471.96 480.57 488.66
#  498.87 509.02 516.4  525.3  533.6  541.25 549.21 553.38 555.9  562.94
#  573.86 582.94 590.48 597.27 604.67 616.86 620.57 626.67 639.03 649.39
#  656.93 666.96 675.   683.74 694.16 700.15 707.77 713.73 723.87 734.06
#  739.08 745.43 753.88 762.54 768.31 778.18 786.65 792.64 799.19 809.34]

# %%
sns.displot(df['dt'], kde_kws={'cumulative': True})

# %%
sns.displot(df)

# %%
from pandas.compat import numpy
sort_dt = np.sort(df)
p = 1. * np.arange(len(sort_dt)) / float(len(sort_dt) - 1)
fig = plt.figure()
fig.suptitle('Кумулята')
ax2 = fig.add_subplot(111)
ax2.plot(sort_dt, p)
ax2.set_ylabel('p')
ax2.grid()
fig.set_figheight (6)
fig.set_figwidth (10)

# %%
print(np.mean(df)) #средннее
print(np.var(df)) #дисперсия
print(np.std(df)) # станжартное отклонение
cv = lambda x: np.std(x, ddof= 1 ) / np.mean (x)
print(cv(df)) # коэф вариации
print(stats.skew(df)) # асимметрию
print(stats.kurtosis(df)) # эксцесс
Median = np.median(df) # медиана
Mode = stats.mode(df)[0]   # index 1 gives frequency
# Out:
# data    8.0934
# dtype: float64
# data    4.922732
# dtype: float64
# data    2.218723
# dtype: float64
# data    0.275521
# dtype: float64
# [-0.34131599]
# [-0.11870698]

# %%
cv = lambda x: np.std(x, ddof= 1 ) / np.mean (x)
res = {'средннее': np.mean(df), 
     'дисперсия': np.var(df), 
     'стандартное отклонение':np.std(df),
     'коэф вариации': cv(df),
     'ассиметрия': stats.skew(df),
    'эксцесс': stats.kurtosis(df) ,
     'медиана': np.median(df),
     'мода': stats.mode(df)[0] }

# %%
print(res)
# Out:
# {'средннее': data    8.0934
# dtype: float64, 'дисперсия': data    4.922732
# dtype: float64, 'стандартное отклонение': data    2.218723
# dtype: float64, 'коэф вариации': data    0.275521
# dtype: float64, 'ассиметрия': array([-0.34131599]), 'эксцесс': array([-0.11870698]), 'медиана': 8.185, 'мода': array([[5.99]])}

# %%
sns_plot = sns.distplot(df['dt'])
fig = sns_plot.get_figure()
fig.set_figheight (6)
fig.set_figwidth (10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sort_dt = np.sort(df)
p = 1. * np.arange(len(sort_dt)) / float(len(sort_dt) - 1)
fig = plt.figure()
#fig.suptitle('Кумулята')
ax2 = fig.add_subplot(111)
ax2.plot(sort_dt, p)
#ax2.set_xlabel('sorted_random_dat')
ax2.set_ylabel('p')
ax2.grid()
fig.set_figheight (6)
fig.set_figwidth (10)
sns_plot = sns.distplot(df['dt'])
fig = sns_plot.get_figure()
fig.set_figheight (6)
fig.set_figwidth (10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns_plt = sns.distplot(df['dt'])
fig = sns_plt.get_figure()
fig.set_figheight (6)
fig.set_figwidth (10)
sns.distplot(df['dt'], kde_kws={'cumulative': True}, label = 'Кумулята')
ax.grid()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-61fde1244a18> in <module>
#       4 fig.set_figwidth (10)
# ...

# %%
dt2 = np.random.randn(5)
print("The data is-",dt2)
sorted_random_data = np.sort(dt2)
np.linspace(0, 1, len(dt2), endpoint=False)
print("The CDF result using linspace =\n",p)
fig = plt.figure()
fig.suptitle('CDF of data points')
ax2 = fig.add_subplot(111)
ax2.plot(sort_dt, p)
ax2.set_xlabel('sort_dt')
ax2.set_ylabel('p')
# Out:
# The data is- [ 0.21825373  0.74442041  1.72581794  1.58331091 -2.31863117]
# The CDF result using linspace =
#  [0.         0.01010101 0.02020202 0.03030303 0.04040404 0.05050505
#  0.06060606 0.07070707 0.08080808 0.09090909 0.1010101  0.11111111
#  0.12121212 0.13131313 0.14141414 0.15151515 0.16161616 0.17171717
#  0.18181818 0.19191919 0.2020202  0.21212121 0.22222222 0.23232323
#  0.24242424 0.25252525 0.26262626 0.27272727 0.28282828 0.29292929
#  0.3030303  0.31313131 0.32323232 0.33333333 0.34343434 0.35353535
#  0.36363636 0.37373737 0.38383838 0.39393939 0.4040404  0.41414141
#  0.42424242 0.43434343 0.44444444 0.45454545 0.46464646 0.47474747
#  0.48484848 0.49494949 0.50505051 0.51515152 0.52525253 0.53535354
#  0.54545455 0.55555556 0.56565657 0.57575758 0.58585859 0.5959596
#  0.60606061 0.61616162 0.62626263 0.63636364 0.64646465 0.65656566
#  0.66666667 0.67676768 0.68686869 0.6969697  0.70707071 0.71717172
# ...

# %%
nor = shapiro(df['dt'])
nor
# Out:
# ShapiroResult(statistic=0.9873858690261841, pvalue=0.4640835225582123)

# %%
int(np.mean(df))
# Out:
# 8

# %%
ztest(df, value= int(np.mean(df)))
# Out:
# (array([0.41885274]), array([0.67532376]))

# %%
z = ztest(df, value= int(np.mean(df)))
z2 = ztest(df, value= int(np.mean(df))+1)

# %%
v = 1 - z2[1]-z[1] 
print(v)
# Out:
# [0.32462834]

# %% [markdown]
# x:   	17	22	10	7	12	21	14	7	20	3
#
# y:	    26	27	22	19	21	26	20	15	30	13

# %%
X = [17, 22, 10, 7, 12, 21, 14, 7, 20, 3]
Y = [26, 27, 22, 19, 21, 26, 20, 15, 30, 13]

# %%
b ={'x': X,'y': Y }
df3 = pd.DataFrame.from_dict(b,orient= 'index')

# %%
df3 = df3.transpose()

# %%
df3
# Out:
#     x   y
# 0  17  26
# 1  22  27
# 2  10  22
# 3   7  19
# 4  12  21
# 5  21  26
# 6  14  20
# 7   7  15
# 8  20  30
# 9   3  13

# %%
fig, ax = plt.subplots()
ax.scatter(X, Y,
           c = 'deeppink')
fig.set_figwidth(8)     #  ширина и
fig.set_figheight(8)    #  высота "Figure"
ax.grid()
plt.show()

# %%
norm = shapiro(X)
norm
# Out:
# ShapiroResult(statistic=0.9433448314666748, pvalue=0.5907965898513794)

# %%
norm = shapiro(Y)
norm
# Out:
# ShapiroResult(statistic=0.9637545347213745, pvalue=0.8276858925819397)

# %%
fig, ax = plt.subplots()
ax.scatter(X, Y,
           c = 'deeppink')
ax.plot(X, res,
           c = 'blue')
fig.set_figwidth(8)     #  ширина и
fig.set_figheight(8)    #  высота "Figure"
ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-742851784965> in <module>
#       2 ax.scatter(X, Y,
#       3            c = 'deeppink')
# ----> 4 ax.plot(X, res,
#       5            c = 'blue')
#       6 fig.set_figwidth(8)     #  ширина и
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
# ...

# %%
model= sm.OLS(df3['y'], df3['x']).fit()
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.943
# Model:                            OLS   Adj. R-squared (uncentered):              0.936
# Method:                 Least Squares   F-statistic:                              148.2
# Date:                Mon, 19 Dec 2022   Prob (F-statistic):                    6.82e-07
# Time:                        08:28:32   Log-Likelihood:                         -31.023
# No. Observations:                  10   AIC:                                      64.05
# Df Residuals:                       9   BIC:                                      64.35
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
